# %% [markdown]
# ## 📖 [The RAG Techniques Book is HERE](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--simple-rag&click=book-buy-amazon&target=https%3A%2F%2Fwww.amazon.com%2Fdp%2FB0D76734SZ%3Ftag%3Ddiamantai-ragnb-20&text=)
#
# **The super extended version of this repository.** The book goes far beyond the notebooks: the **intuition** behind every technique, **side-by-side comparisons** showing when each approach wins (and when it quietly fails), and **illustrations** that make the tricky parts finally click.
#
# ⏳ **Launch window only: $0.99.** The price goes up once the launch ends, and readers who grab it now lock in the lowest price it will ever have.
#
# ### 👉 [Get the book on Amazon before the price changes](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--simple-rag&click=book-buy-amazon&target=https%3A%2F%2Fwww.amazon.com%2Fdp%2FB0D76734SZ%3Ftag%3Ddiamantai-ragnb-20&text=)
#
# ---

# %% [markdown]
# # Simple RAG (Retrieval-Augmented Generation) System
#
# ## Overview
#
# This code implements a basic Retrieval-Augmented Generation (RAG) system for processing and querying PDF documents. The system encodes the document content into a vector store, which can then be queried to retrieve relevant information.
#
# ## Key Components
#
# 1. PDF processing and text extraction
# 2. Text chunking for manageable processing
# 3. Vector store creation using [FAISS](https://engineering.fb.com/2017/03/29/data-infrastructure/faiss-a-library-for-efficient-similarity-search/) and OpenAI embeddings
# 4. Retriever setup for querying the processed documents
# 5. Evaluation of the RAG system
#
# ## Method Details
#
# ### Document Preprocessing
#
# 1. The PDF is loaded using PyPDFLoader.
# 2. The text is split into chunks using RecursiveCharacterTextSplitter with specified chunk size and overlap.
#
# ### Text Cleaning
#
# A custom function `replace_t_with_space` is applied to clean the text chunks. This likely addresses specific formatting issues in the PDF.
#
# ### Vector Store Creation
#
# 1. OpenAI embeddings are used to create vector representations of the text chunks.
# 2. A FAISS vector store is created from these embeddings for efficient similarity search.
#
# ### Retriever Setup
#
# 1. A retriever is configured to fetch the top 2 most relevant chunks for a given query.
#
# ### Encoding Function
#
# The `encode_pdf` function encapsulates the entire process of loading, chunking, cleaning, and encoding the PDF into a vector store.
#
# ## Key Features
#
# 1. Modular Design: The encoding process is encapsulated in a single function for easy reuse.
# 2. Configurable Chunking: Allows adjustment of chunk size and overlap.
# 3. Efficient Retrieval: Uses FAISS for fast similarity search.
# 4. Evaluation: Includes a function to evaluate the RAG system's performance.
#
# ## Usage Example
#
# The code includes a test query: "What is the main cause of climate change?". This demonstrates how to use the retriever to fetch relevant context from the processed document.
#
# ## Evaluation
#
# The system includes an `evaluate_rag` function to assess the performance of the retriever, though the specific metrics used are not detailed in the provided code.
#
# ## Benefits of this Approach
#
# 1. Scalability: Can handle large documents by processing them in chunks.
# 2. Flexibility: Easy to adjust parameters like chunk size and number of retrieved results.
# 3. Efficiency: Utilizes FAISS for fast similarity search in high-dimensional spaces.
# 4. Integration with Advanced NLP: Uses OpenAI embeddings for state-of-the-art text representation.
#
# ## Conclusion
#
# This simple RAG system provides a solid foundation for building more complex information retrieval and question-answering systems. By encoding document content into a searchable vector store, it enables efficient retrieval of relevant information in response to queries. This approach is particularly useful for applications requiring quick access to specific information within large documents or document collections.

# %% [markdown]
# # Package Installation and Imports
#
# The cell below installs all necessary packages required to run this notebook.

# %%
# Install required packages
# %pip install pypdf==5.6.0
# %pip install PyMuPDF==1.26.1
# %pip install python-dotenv==1.1.0
# %pip install langchain-community==0.3.25
# %pip install langchain_openai==0.3.23
# %pip install rank_bm25==0.2.2
# %pip install faiss-cpu==1.11.0
# %pip install deepeval==3.1.0
# Out:
# Requirement already satisfied: pypdf==5.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (5.6.0)
# Requirement already satisfied: PyMuPDF==1.26.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (1.26.1)
# Requirement already satisfied: python-dotenv==1.1.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: langchain-community==0.3.25 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (0.3.25)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (0.3.84)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (0.3.28)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (2.0.49)
# Requirement already satisfied: requests<3,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (2.33.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (2.14.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (0.3.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-community==0.3.25) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.25) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.25) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.25) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.25->langchain-community==0.3.25) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.25->langchain-community==0.3.25) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-community==0.3.25) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-community==0.3.25) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-community==0.3.25) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-community==0.3.25) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.65->langchain-community==0.3.25) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (3.11.8)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (0.23.0)
# Requirement already satisfied: anyio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (4.13.0)
# Requirement already satisfied: certifi in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (1.0.9)
# Requirement already satisfied: idna in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community==0.3.25) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community==0.3.25) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community==0.3.25) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.25->langchain-community==0.3.25) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.25) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.25) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain-community==0.3.25) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.3.25) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.25) (1.1.0)
# Requirement already satisfied: langchain_openai==0.3.23 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (0.3.23)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain_openai==0.3.23) (0.3.84)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain_openai==0.3.23) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain_openai==0.3.23) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (2.13.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (3.11.8)
# Requirement already satisfied: requests<3,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (2.33.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.23.0)
# Requirement already satisfied: anyio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (4.13.0)
# Requirement already satisfied: certifi in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (1.0.9)
# Requirement already satisfied: idna in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain_openai==0.3.23) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain_openai==0.3.23) (0.14.0)
# Requirement already satisfied: sniffio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain_openai==0.3.23) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain_openai==0.3.23) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain_openai==0.3.23) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from tiktoken<1,>=0.7->langchain_openai==0.3.23) (2026.4.4)
# Requirement already satisfied: rank_bm25==0.2.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (0.2.2)
# Requirement already satisfied: numpy in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from rank_bm25==0.2.2) (2.4.4)
# Requirement already satisfied: faiss-cpu==1.11.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (1.11.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from faiss-cpu==1.11.0) (2.4.4)
# Requirement already satisfied: packaging in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from faiss-cpu==1.11.0) (25.0)
# Requirement already satisfied: deepeval==3.1.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (3.1.0)
# Requirement already satisfied: aiohttp in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (3.13.5)
# Requirement already satisfied: anthropic in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.97.0)
# Requirement already satisfied: click<8.2.0,>=8.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (8.1.8)
# Requirement already satisfied: google-genai<2.0.0,>=1.9.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.74.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.67.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.80.0)
# Requirement already satisfied: nest_asyncio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.6.0)
# Requirement already satisfied: ollama in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.6.2)
# Requirement already satisfied: openai in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.109.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.24.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.41.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.24.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.41.1)
# Requirement already satisfied: portalocker in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (3.2.0)
# Requirement already satisfied: posthog<4.0.0,>=3.23.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (3.25.0)
# Requirement already satisfied: pyfiglet in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.0.4)
# Requirement already satisfied: pytest in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (9.0.3)
# Requirement already satisfied: pytest-asyncio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (1.3.0)
# Requirement already satisfied: pytest-repeat in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.9.4)
# Requirement already satisfied: pytest-rerunfailures<13.0,>=12.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (12.0)
# Requirement already satisfied: pytest-xdist in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (3.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (2.33.1)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (13.9.4)
# Requirement already satisfied: sentry-sdk in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (2.58.0)
# Requirement already satisfied: setuptools in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (82.0.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.9.0)
# Requirement already satisfied: tenacity<=9.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (9.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (4.67.3)
# Requirement already satisfied: typer<1.0.0,>=0.9 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.23.1)
# Requirement already satisfied: wheel in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from deepeval==3.1.0) (0.47.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (2.50.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (2.13.3)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (1.9.0)
# Requirement already satisfied: sniffio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (3.13)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (47.0.0)
# Requirement already satisfied: certifi in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.24.0->deepeval==3.1.0) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.24.0->deepeval==3.1.0) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->deepeval==3.1.0) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->deepeval==3.1.0) (1.41.1)
# Requirement already satisfied: opentelemetry-proto==1.41.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->deepeval==3.1.0) (1.41.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-proto==1.41.1->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.24.0->deepeval==3.1.0) (6.33.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<2.0.0,>=1.24.0->deepeval==3.1.0) (0.62b1)
# Requirement already satisfied: six>=1.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.23.0->deepeval==3.1.0) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.23.0->deepeval==3.1.0) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.23.0->deepeval==3.1.0) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from posthog<4.0.0,>=3.23.0->deepeval==3.1.0) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.4.2)
# Requirement already satisfied: packaging>=17.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pytest-rerunfailures<13.0,>=12.0->deepeval==3.1.0) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->deepeval==3.1.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->deepeval==3.1.0) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from rich<14.0.0,>=13.6.0->deepeval==3.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from rich<14.0.0,>=13.6.0->deepeval==3.1.0) (2.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.9->deepeval==3.1.0) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.9->deepeval==3.1.0) (0.0.4)
# Requirement already satisfied: cffi>=2.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->deepeval==3.1.0) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.9.0->deepeval==3.1.0) (0.6.3)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pytest->deepeval==3.1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pytest->deepeval==3.1.0) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp->deepeval==3.1.0) (1.23.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from anthropic->deepeval==3.1.0) (0.18.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from anthropic->deepeval==3.1.0) (0.14.0)
# Requirement already satisfied: execnet>=2.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pytest-xdist->deepeval==3.1.0) (2.1.2)

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')

# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .
# Out:
# fatal: destination path 'RAG_TECHNIQUES' already exists and is not an empty directory.

# %%
import os
import sys
from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable (comment out if not using OpenAI)
if not os.environ["OPENAI_API_KEY"]:
    os.environ["OPENAI_API_KEY"] = input("Please enter your OpenAI API key: ")

# Original path append replaced for Colab compatibility

from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from helper_functions import (EmbeddingProvider,
                              retrieve_context_per_question,
                              replace_t_with_space,
                              get_langchain_embedding_provider,
                              show_context)

from evaluation.evalute_rag import evaluate_rag

from langchain.vectorstores import FAISS

# %% [markdown]
# ### Read Docs

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# Out:
# --2026-05-03 15:52:10--  https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8001::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206372 (202K) [application/octet-stream]
# Saving to: ‘data/Understanding_Climate_Change.pdf’
#
# data/Understanding_ 100%[===================>] 201.54K  --.-KB/s    in 0.03s
#
# 2026-05-03 15:52:10 (6.55 MB/s) - ‘data/Understanding_Climate_Change.pdf’ saved [206372/206372]

# %%
path = "data/Understanding_Climate_Change.pdf"

# %% [markdown]
# ### Encode document

# %%
def encode_pdf(path, chunk_size=1000, chunk_overlap=200):
    """
    Encodes a PDF book into a vector store using OpenAI embeddings.

    Args:
        path: The path to the PDF file.
        chunk_size: The desired size of each text chunk.
        chunk_overlap: The amount of overlap between consecutive chunks.

    Returns:
        A FAISS vector store containing the encoded book content.
    """

    # Load PDF documents
    loader = PyPDFLoader(path)
    documents = loader.load()

    # Split documents into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap, length_function=len
    )
    texts = text_splitter.split_documents(documents)
    cleaned_texts = replace_t_with_space(texts)

    # Create embeddings (Tested with OpenAI and Amazon Bedrock)
    embeddings = get_langchain_embedding_provider(EmbeddingProvider.OPENAI)
    #embeddings = get_langchain_embedding_provider(EmbeddingProvider.AMAZON_BEDROCK)

    # Create vector store
    vectorstore = FAISS.from_documents(cleaned_texts, embeddings)

    return vectorstore

# %%
chunks_vector_store = encode_pdf(path, chunk_size=1000, chunk_overlap=200)

# %% [markdown]
# ### Create retriever

# %%
chunks_query_retriever = chunks_vector_store.as_retriever(search_kwargs={"k": 2})

# %% [markdown]
# ### Test retriever

# %%
test_query = "What is the main cause of climate change?"
context = retrieve_context_per_question(test_query, chunks_query_retriever)
show_context(context)
# Out:
# Context 1:
# Chapter 2: Causes of Climate Change
# Greenhouse Gases
# The primary cause of recent climate change is the increase in greenhouse gases in the
# atmosphere. Greenhouse gases, such as carbon dioxide (CO2), methane (CH4), and nitrous
# oxide (N2O), trap heat from the sun, creating a "greenhouse effect." This effect is essential
# for life on Earth, as it keeps the planet warm enough to support life. However, human
# activities have intensified this natural process, leading to a warmer climate.
# Fossil Fuels
# Burning fossil fuels for energy releases large amounts of CO2. This includes coal, oil, and
# natural gas used for electricity, heating, and transportation. The industrial revolution marked
# the beginning of a significant increase in fossil fuel consumption, which continues to rise
# today.
# Coal
#
#
# Context 2:
# Most of these climate changes are attributed to very small variations in Earth's orbit that
# change the amount of solar energy our planet receives. During the Holocene epoch, which
# began at the end of the last ice age, human societies flourished, but the industrial era has seen
# unprecedented changes.
# Modern Observations
# Modern scientific observations indicate a rapid increase in global temperatures, sea levels,
# and extreme weather events. The Intergovernmental Panel on Climate Change (IPCC) has
# documented these changes extensively. Ice core samples, tree rings, and ocean sediments
# provide a historical record that scientists use to understand past climate conditions and
# predict future trends. The evidence overwhelmingly shows that recent changes are primarily
# driven by human activities, particularly the emission of greenhouse gases.
# Chapter 2: Causes of Climate Change
# Greenhouse Gases
# The primary cause of recent climate change is the increase in greenhouse gases in the

# %% [markdown]
# ### Evaluate results

# %%
#Note - this currently works with OPENAI only
evaluate_rag(chunks_query_retriever)
# Out:
# {'questions': ['1. **Multiple Choice Question:**',
#   '   What is the primary cause of the recent acceleration in climate change?',
#   '   A) Solar radiation variations',
#   '   B) Natural geological processes',
#   '   C) Human-induced emissions of greenhouse gases',
#   '   D) Increased volcanic activity',
#   '',
#   '2. **True or False Question:**',
#   '   True or False: The melting of polar ice caps has no effect on global sea levels.',
#   '',
#   '3. **Short Answer Question:**',
#   '   Explain how deforestation contributes to climate change.',
#   '',
#   '4. **Data Interpretation Question:**',
#   '   Given the following data on annual CO2 emissions by sector: Transportation (28%), Electricity and heat production (25%), Industry (21%), Agriculture (14%), and Residential (12%), identify which sector contributes most to CO2 emissions and discuss one strategy to reduce emissions in that sector.',
#   '',
#   '5. **Essay Question:**',
#   '   Discuss the potential impacts of climate change on global agriculture. Include in your discussion how changes in temperature, precipitation patterns, and extreme weather events could affect food production and food security worldwide.'],
#  'results': ['```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context discusses climate policy, international agreements, and national policies related to climate change. However, the question is not provided in the prompt, making it impossible to assess relevance accurately. Assuming the question might relate to climate policy based on the context, the relevance is still low as there is no specific question addressed directly in the provided text.\n- **Completeness (1/5)**: Without knowing the specific question, it\'s difficult to judge completeness. However, assuming a general question about climate policy, the text does not provide a comprehensive overview or detailed explanation suitable for a multiple-choice question answer.\n- **Conciseness (2/5)**: The text provides a broad discussion on climate policy and agreements but includes several aspects that might not be necessary for answering a specific question. It lacks focus and contains potentially irrelevant information depending on the actual question.',
#   '```json\n{\n    "Relevance": 5,\n    "Completeness": 5,\n    "Conciseness": 4\n}\n```\n\nExplanation:\n1. **Relevance**: The retrieved context directly addresses the question about the primary cause of recent climate change, identifying the increase in greenhouse gases as the main factor. This directly answers the question posed, making it highly relevant.\n2. **Completeness**: The context provides a comprehensive explanation of the role of greenhouse gases, the impact of human activities, and the historical context of fossil fuel consumption. It also mentions modern observations and scientific documentation, which supports the explanation and provides a thorough understanding of the issue.\n3. **Conciseness**: The context is mostly focused on the topic of climate change causes, particularly greenhouse gases. However, there is a brief mention of Earth\'s orbital variations which, while related to climate change in a broader sense, is not directly relevant to the question about recent accelerations attributed to human activities. This slightly detracts from the conciseness.',
#   '```json\n{\n    "Relevance": 2,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (2/5)**: The retrieved context briefly mentions the impact of small variations in Earth\'s orbit on the amount of solar energy received, which is somewhat relevant to the question about solar radiation variations. However, the majority of the context discusses broader climate change issues, which are not directly focused on solar radiation variations.\n- **Completeness (1/5)**: The context does not provide a comprehensive explanation or detailed information specifically about solar radiation variations, their causes, measurements, or direct impacts, which would be necessary to fully address the question.\n- **Conciseness (2/5)**: The context includes a lot of information unrelated to the specific question about solar radiation variations, such as details on climate change effects, greenhouse gases, and historical climate data, making it less concise and focused.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context discusses climate change and its effects such as extreme weather events, ocean acidification, and impacts on ecosystems. However, the question specifically asks about "natural geological processes," which generally refers to processes like volcanic activity, earthquakes, erosion, sedimentation, and similar geological phenomena. The retrieved context does not address these topics, making it largely irrelevant to the question.\n- **Completeness (1/5)**: Since the retrieved context does not address natural geological processes, it lacks the necessary information to answer the question. It is incomplete in the context of the question asked.\n- **Conciseness (2/5)**: The retrieved context is somewhat focused on the topic of climate change and its impacts, but since this topic is irrelevant to the question about natural geological processes, the information can be considered extraneous in this context. Thus, it is not concise with respect to the specific question asked.',
#   '```json\n{\n    "Relevance": 5,\n    "Completeness": 4,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (5)**: The retrieved context is highly relevant to the question about human-induced emissions of greenhouse gases. It discusses the role of greenhouse gases in climate change and specifically highlights human activities such as burning fossil fuels and deforestation as key contributors.\n- **Completeness (4)**: The context provides a comprehensive overview of the main sources of human-induced greenhouse gas emissions, including fossil fuels and deforestation. However, it could be enhanced by including more details on other significant sources or factors, such as industrial processes, livestock emissions, and waste management.\n- **Conciseness (3)**: While the context is generally focused on the topic, it includes some details that are less directly related to the question, such as the description of natural gas as a "bridge fuel" and the specific mention of tropical deforestation. These details, while informative, slightly divert from the core focus on human-induced emissions.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context discusses various environmental issues such as heatwaves, changing seasons, melting ice, rising sea levels, droughts, flooding, and ocean acidification. However, it does not mention anything about volcanic activity, which is the specific topic of the question.\n- **Completeness (1/5)**: Since the context does not address volcanic activity at all, it lacks the necessary information to answer the question about increased volcanic activity.\n- **Conciseness (2/5)**: While the context is somewhat focused on environmental changes and their impacts, it includes a broad range of topics that are irrelevant to the specific question about volcanic activity, thus reducing its conciseness in this context.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context does not directly answer or relate to a specific question, as the question itself is missing in the provided text. Therefore, it\'s impossible to assess relevance without knowing the exact question.\n- **Completeness (1/5)**: Since the question is not provided, it\'s unclear whether the context contains all necessary information to answer it. The context broadly discusses strategies and principles for addressing climate change, but without a specific question, completeness cannot be accurately rated.\n- **Conciseness (3/5)**: The text is relatively focused on the topic of sustainable approaches to climate change, maintaining a consistent theme throughout. However, without knowing the specific question, it\'s difficult to determine if all information in the text is relevant. The rating reflects the text\'s general focus rather than its alignment with an unknown question.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context discusses youth engagement in climate action, impacts of climate change on ecosystems, and related topics. However, it does not address a specific "True or False" question, making it largely irrelevant to the query.\n- **Completeness (1/5)**: Since the context does not address a specific "True or False" question, it lacks the necessary information to be considered complete in relation to the question asked.\n- **Conciseness (2/5)**: The context provides detailed information about various aspects of climate change and its effects, but it includes a lot of information that is not pertinent to a specific "True or False" question, making it not concise for the purpose of answering the question.',
#   '```json\n{\n    "Relevance": 5,\n    "Completeness": 5,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (5)**: The retrieved context directly addresses the question by discussing the impact of polar ice cap melting on sea levels, which is the core issue in the question.\n- **Completeness (5)**: The context provides comprehensive information about the effects of ice melting, including its contribution to sea level rise and the broader implications for global climate, ecosystems, and human communities.\n- **Conciseness (3)**: While the context is rich in relevant details, it includes broader impacts such as effects on weather patterns, ecosystems, and human activities, which, while related, extend beyond the specific focus of the question about sea levels. This makes the context less concise.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context does not directly answer or relate to a specific question, as the question itself is missing in the provided text. Therefore, it\'s impossible to assess relevance without knowing the exact question.\n- **Completeness (1/5)**: Since the question is not provided, it\'s unclear whether the context contains all necessary information to answer it. Thus, it\'s rated low for completeness.\n- **Conciseness (3/5)**: The context is generally focused on the topic of addressing climate change through various approaches and principles. However, without knowing the specific question, it\'s difficult to determine if all included information is relevant, but the text itself is structured and focused on its themes.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 1\n}\n```\n\nExplanation:\n- **Relevance**: The rating is low because the retrieved context does not directly address or answer any specific short answer question. It discusses various environmental issues related to climate change, but without knowing the exact question, it\'s difficult to assess relevance. Assuming the question might be about the impacts of climate change, the context is still too broad and not focused on a specific query.\n- **Completeness**: The context is not complete in terms of answering a specific question as it lacks a focused response or detailed explanation on a particular topic. It broadly covers multiple unrelated aspects of climate change.\n- **Conciseness**: The information provided is not concise as it includes multiple topics that may not be relevant to the specific question asked. It diverges into various environmental issues without a clear focus.',
#   '```json\n{\n    "Relevance": 4,\n    "Completeness": 3,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (4)**: The retrieved context is highly relevant as it discusses the impact of deforestation on climate change, particularly focusing on carbon storage and release. It specifically addresses how deforestation in tropical and boreal forests contributes to climate change, which is directly related to the question.\n- **Completeness (3)**: The context provides a good overview of how deforestation contributes to climate change by releasing stored carbon dioxide. However, it could be more complete by discussing additional effects such as changes in land albedo, disruption of the water cycle, and other indirect impacts on climate.\n- **Conciseness (2)**: The context includes sections on agriculture, livestock emissions, and natural gas that are less directly related to the question about deforestation. These sections dilute the focus on deforestation\'s role in climate change, making the information less concise.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context does not directly answer or relate to a specific question, as the question itself is missing in the provided text. Therefore, it\'s impossible to assess relevance without knowing the exact question.\n- **Completeness (1/5)**: Since the question is not provided, it\'s unclear whether the context contains all necessary information to answer it. Thus, it\'s rated low for completeness.\n- **Conciseness (3/5)**: The context is generally focused on the topic of addressing climate change through various approaches and principles. However, without knowing the specific question, it\'s difficult to determine if all included information is relevant, but the text itself is structured and focused on its themes.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context does not directly address or relate to a specific data interpretation question. It discusses various impacts of climate change and citizen science, which are not directly linked to interpreting data or a specific dataset.\n- **Completeness (1/5)**: Since the context does not address a specific data interpretation question, it lacks the necessary information to be considered complete in relation to the question asked.\n- **Conciseness (2/5)**: The context, while somewhat focused on climate change and its impacts, includes multiple unrelated topics such as citizen science and health impacts, which dilute the focus and introduce irrelevant information in relation to a data interpretation question.',
#   '```json\n{\n    "Relevance": 3,\n    "Completeness": 2,\n    "Conciseness": 2\n}\n```\n\nExplanation:\n- **Relevance (3/5)**: The retrieved context discusses various sources of CO2 emissions, including coal, oil, and natural gas, which are relevant to the question about CO2 emissions by sector. It also touches on strategies to reduce emissions in the transportation and industrial sectors. However, it does not directly address the specific sectors listed in the question (e.g., Electricity and heat production, Agriculture, Residential) in terms of their contribution percentages or targeted reduction strategies.\n  \n- **Completeness (2/5)**: The context lacks a direct answer to which sector contributes the most to CO2 emissions based on the provided data. It also does not provide a strategy specifically for the sector that contributes the most (Transportation, 28%). While it mentions strategies for reducing emissions in transportation and industry, it does not cover all sectors mentioned in the question or provide a comprehensive strategy for the leading sector.\n\n- **Conciseness (2/5)**: The context includes detailed descriptions of different fossil fuels and their roles in CO2 emissions, which, while informative, are not directly focused on answering the question about the specific sectors and strategies for reducing emissions in the highest contributing sector. There is extraneous information about the global role and economic implications of these fuels, which dilutes the focus needed to directly address the question.',
#   '```json\n{\n    "Relevance": 1,\n    "Completeness": 1,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (1/5)**: The retrieved context does not directly answer or relate to a specific question, as the question itself is missing in the provided text. Therefore, it\'s impossible to assess relevance without knowing the exact question.\n- **Completeness (1/5)**: Since the question is not provided, it\'s unclear whether the context contains all necessary information to answer it. Thus, it\'s rated low for completeness.\n- **Conciseness (3/5)**: The context is generally focused on the topic of addressing climate change through various approaches and principles. However, without knowing the specific question, it\'s difficult to determine if all included information is relevant, but the text itself is structured and focused on its themes.',
#   '```json\n{\n    "Relevance": 3,\n    "Completeness": 2,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (3/5)**: The retrieved context discusses climate change, youth engagement, and technology\'s role in mitigation, which are somewhat relevant to an essay question about climate change. However, the specific question is not provided, so the relevance is moderately rated.\n- **Completeness (2/5)**: The context provides an overview of several aspects related to climate change but lacks depth in any specific area that might be required for a comprehensive essay. It touches on various topics without delving deeply into any, which might not fully satisfy an essay question\'s requirements.\n- **Conciseness (3/5)**: The context includes relevant information about climate change and its mitigation but also contains broad statements about youth engagement and global cooperation which might not be directly pertinent to the specific focus of an essay question on climate change, assuming it requires technical and detailed analysis.',
#   '```json\n{\n    "Relevance": 3,\n    "Completeness": 2,\n    "Conciseness": 3\n}\n```\n\nExplanation:\n- **Relevance (3/5)**: The retrieved context mentions the effects of climate change such as rising temperatures and changing seasons, which are relevant to the question about impacts on global agriculture. However, it lacks specific details on how these changes directly affect food production and food security.\n- **Completeness (2/5)**: The context does not fully address the question as it misses detailed discussions on precipitation patterns and extreme weather events, and their specific impacts on agriculture. It also does not provide a comprehensive analysis of global food security.\n- **Conciseness (3/5)**: The context includes some relevant information about the effects of climate change on agriculture but also contains general statements about climate change and technology that do not directly contribute to the question about agriculture. This dilutes the focus needed for a concise response.'],
#  'average_scores': None}

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--simple-rag)
