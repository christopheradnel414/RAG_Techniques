# %% [markdown]
# ## 📖 [The RAG Techniques Book is HERE](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--choose-chunk-size&click=book-buy-amazon&target=https%3A%2F%2Fwww.amazon.com%2Fdp%2FB0D76734SZ%3Ftag%3Ddiamantai-ragnb-20&text=)
#
# **The super extended version of this repository.** The book goes far beyond the notebooks: the **intuition** behind every technique, **side-by-side comparisons** showing when each approach wins (and when it quietly fails), and **illustrations** that make the tricky parts finally click.
#
# ⏳ **Launch window only: $0.99.** The price goes up once the launch ends, and readers who grab it now lock in the lowest price it will ever have.
#
# ### 👉 [Get the book on Amazon before the price changes](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--choose-chunk-size&click=book-buy-amazon&target=https%3A%2F%2Fwww.amazon.com%2Fdp%2FB0D76734SZ%3Ftag%3Ddiamantai-ragnb-20&text=)
#
# ---

# %% [markdown]
# # Package Installation and Imports
#
# The cell below installs all necessary packages required to run this notebook.

# %%
# Install required packages
# %pip install llama-index openai python-dotenv
# %pip install spacy
# Out:
# Requirement already satisfied: llama-index in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (0.14.21)
# Requirement already satisfied: openai in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.21 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index) (0.14.21)
# Requirement already satisfied: llama-index-embeddings-openai<0.7,>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index) (0.6.0)
# Requirement already satisfied: llama-index-llms-openai<0.8,>=0.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index) (0.7.7)
# Requirement already satisfied: nltk>=3.9.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index) (3.9.4)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (3.13.5)
# Requirement already satisfied: aiosqlite in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.4.2)
# Requirement already satisfied: dataclasses-json in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2026.4.0)
# Requirement already satisfied: httpx in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.20.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (3.6.1)
# Requirement already satisfied: numpy in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.4.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (12.2.0)
# Requirement already satisfied: platformdirs in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.9.6)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.13.3)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.33.1)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (82.0.1)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.0.49)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.12.0)
# Requirement already satisfied: tinytag>=2.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.2.1)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-core<0.15.0,>=0.14.21->llama-index) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.23.0)
# Requirement already satisfied: griffe in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.0.2)
# Requirement already satisfied: jinja2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.1.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.16.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.2)
# Requirement already satisfied: click in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from nltk>=3.9.3->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from nltk>=3.9.3->llama-index) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from nltk>=3.9.3->llama-index) (2026.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.21->llama-index) (25.0)
# Requirement already satisfied: griffecli==2.0.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.21->llama-index) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Collecting spacy
#   Downloading spacy-3.8.14-cp313-cp313-macosx_10_13_x86_64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-macosx_10_13_x86_64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-macosx_10_13_x86_64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.2 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp313-cp313-macosx_10_13_x86_64.whl.metadata (14 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (2.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (2.13.3)
# Requirement already satisfied: jinja2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.3)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: httpx>=0.24.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.14-cp313-cp313-macosx_10_13_x86_64.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 31.8 MB/s  0:00:00 eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp313-cp313-macosx_10_13_x86_64.whl (43 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-macosx_10_13_x86_64.whl (27 kB)
# Downloading preshed-3.0.13-cp313-cp313-macosx_10_13_x86_64.whl (137 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp313-cp313-macosx_10_13_x86_64.whl (656 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 656.8/656.8 kB 9.9 MB/s  0:00:00
# Downloading thinc-8.3.13-cp313-cp313-macosx_10_13_x86_64.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.3/817.3 kB 10.1 MB/s  0:00:00
# Downloading blis-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 32.7 MB/s  0:00:00m0:00:01
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Downloading smart_open-7.6.0-py3-none-any.whl (64 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, thinc, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [spacy]m14/15 [spacy]]ue]]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 smart-open-7.6.0 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
import random

nest_asyncio.apply()
from dotenv import load_dotenv

from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.prompts import PromptTemplate

from llama_index.core.evaluation import (
    DatasetGenerator,
    FaithfulnessEvaluator,
    RelevancyEvaluator
)
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings

import openai
import time
import os
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Read Docs

# %%
data_dir = "../data"
documents = SimpleDirectoryReader(data_dir).load_data()

# %% [markdown]
# ### Create evaluation questions and pick k out of them

# %%
gpt5 = OpenAI(temperature=0, model="gpt-5-nano")
Settings.llm = gpt5

num_eval_questions = 25

eval_documents = documents[0:20]
data_generator = DatasetGenerator.from_documents(eval_documents)
eval_questions = data_generator.generate_questions_from_nodes()
k_eval_questions = random.sample(eval_questions, num_eval_questions)
# Out:
# /Users/christopheradnel/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/evaluation/dataset_generation.py:201: DeprecationWarning: Call to deprecated class DatasetGenerator. (Deprecated in favor of `RagDatasetGenerator` which should be used instead.)
#   return cls(
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 462. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 469. Please try again in 140ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 264. Please try again in 79ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 303. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 417. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 299. Please try again in 89ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 407. Please try again in 122ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 501. Please try again in 150ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 240. Please try again in 72ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 302. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 417. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 397. Please try again in 119ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 348. Please try again in 104ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 300. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 395. Please try again in 118ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 379. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 358. Please try again in 107ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 344. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 331. Please try again in 99ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 345. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 464. Please try again in 139ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 461. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 374. Please try again in 112ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 444. Please try again in 133ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 470. Please try again in 141ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 388. Please try again in 116ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 463. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 393. Please try again in 117ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 365. Please try again in 109ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 595. Please try again in 178ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 339. Please try again in 101ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 483. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 477. Please try again in 143ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 379. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 387. Please try again in 116ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 432. Please try again in 129ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 472. Please try again in 141ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 467. Please try again in 140ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 506. Please try again in 151ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 412. Please try again in 123ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 388. Please try again in 116ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 421. Please try again in 126ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 376. Please try again in 112ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 376. Please try again in 112ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 454. Please try again in 136ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 512. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 577. Please try again in 173ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 491. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 617. Please try again in 185ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 397. Please try again in 119ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 588. Please try again in 176ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 584. Please try again in 175ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 444. Please try again in 133ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 507. Please try again in 152ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 418. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 513. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 419. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 416. Please try again in 124ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 411. Please try again in 123ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 463. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 399. Please try again in 119ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 429. Please try again in 128ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 438. Please try again in 131ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 486. Please try again in 145ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 504. Please try again in 151ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 492. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 367. Please try again in 110ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 464. Please try again in 139ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 461. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 576. Please try again in 172ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 463. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 441. Please try again in 132ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 417. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 433. Please try again in 129ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 467. Please try again in 140ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 461. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 562. Please try again in 168ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 599. Please try again in 179ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 446. Please try again in 133ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 549. Please try again in 164ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 555. Please try again in 166ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 601. Please try again in 180ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 653. Please try again in 195ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 756. Please try again in 226ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 723. Please try again in 216ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 732. Please try again in 219ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 716. Please try again in 214ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 724. Please try again in 217ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 721. Please try again in 216ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 286. Please try again in 85ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# Retrying llama_index.llms.openai.base.OpenAI._achat in 1.0 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 927. Please try again in 278ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}.
# ...
#     208 with self.callback_manager.event(
#     209     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     210 ) as query_event:
#     211     nodes = await self.aretrieve(query_bundle)
# --> 213     response = await self._response_synthesizer.asynthesize(
#     214         query=query_bundle,
#     215         nodes=nodes,
#     216     )
#     218     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     220 return response
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:464, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     456 self.span_enter(
#     457     id_=id_,
#     458     bound_args=bound_args,
#    (...)    461     tags=tags,
#     462 )
#     463 try:
# --> 464     result = await func(*args, **kwargs)
#     465 except BaseException as e:
#     466     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/base.py:300, in BaseSynthesizer.asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     294     query = QueryBundle(query_str=query)
#     296 with self._callback_manager.event(
#     297     CBEventType.SYNTHESIZE,
#     298     payload={EventPayload.QUERY_STR: query.query_str},
#     299 ) as event:
# --> 300     response_str = await self.aget_response(
#     301         query_str=query.query_str,
#     302         text_chunks=[
#     303             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     304         ],
#     305         **response_kwargs,
#     306     )
#     308     additional_source_nodes = additional_source_nodes or []
#     309     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:464, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     456 self.span_enter(
#     457     id_=id_,
#     458     bound_args=bound_args,
#    (...)    461     tags=tags,
#     462 )
#     463 try:
# --> 464     result = await func(*args, **kwargs)
#     465 except BaseException as e:
#     466     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/compact_and_refine.py:23, in CompactAndRefine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      14 @dispatcher.span
#      15 async def aget_response(
#      16     self,
#    (...)     20     **response_kwargs: Any,
#      21 ) -> RESPONSE_TEXT_TYPE:
#      22     compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 23     return await super().aget_response(
#      24         query_str=query_str,
#      25         text_chunks=compact_texts,
#      26         prev_response=prev_response,
#      27         **response_kwargs,
#      28     )
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:464, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     456 self.span_enter(
#     457     id_=id_,
#     458     bound_args=bound_args,
#    (...)    461     tags=tags,
#     462 )
#     463 try:
# --> 464     result = await func(*args, **kwargs)
#     465 except BaseException as e:
#     466     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/refine.py:362, in Refine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     358 for text_chunk in text_chunks:
#     359     if prev_response is None:
#     360         # if this is the first chunk, and text chunk already
#     361         # is an answer, then return it
# --> 362         response = await self._agive_response_single(
#     363             query_str, text_chunk, **response_kwargs
#     364         )
#     365     else:
#     366         response = await self._arefine_response_single(
#     367             prev_response, query_str, text_chunk, **response_kwargs
#     368         )
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/refine.py:481, in Refine._agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     479 if response is None and not self._streaming:
#     480     try:
# --> 481         structured_response = await program.acall(
#     482             context_str=cur_text_chunk,
#     483             **response_kwargs,
#     484         )
#     485         structured_response = cast(
#     486             StructuredRefineResponse, structured_response
#     487         )
#     488         query_satisfied = structured_response.query_satisfied
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/refine.py:101, in DefaultRefineProgram.acall(self, *args, **kwds)
#      99         answer = answer.model_dump_json()
#     100 else:
# --> 101     answer = await self._llm.apredict(
#     102         self._prompt,
#     103         **kwds,
#     104     )
#     105 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:464, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     456 self.span_enter(
#     457     id_=id_,
#     458     bound_args=bound_args,
#    (...)    461     tags=tags,
#     462 )
#     463 try:
# --> 464     result = await func(*args, **kwargs)
#     465 except BaseException as e:
#     466     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/llms/llm.py:730, in LLM.apredict(self, prompt, **prompt_args)
#     728 if self.metadata.is_chat_model:
#     729     messages = self._get_messages(prompt, **prompt_args)
# --> 730     chat_response = await self.achat(messages)
#     731     output = chat_response.message.content or ""
#     732 else:
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:464, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     456 self.span_enter(
#     457     id_=id_,
#     458     bound_args=bound_args,
#    (...)    461     tags=tags,
#     462 )
#     463 try:
# --> 464     result = await func(*args, **kwargs)
#     465 except BaseException as e:
#     466     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/core/llms/callbacks.py:79, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_async_llm_chat(_self, messages, **kwargs)
#      76     await _self.rate_limiter.async_acquire()
#      78 try:
# ---> 79     f_return_val = await f(_self, messages, **kwargs)
#      80 except BaseException as e:
#      81     callback_manager.on_event_end(
#      82         CBEventType.LLM,
#      83         payload={EventPayload.EXCEPTION: e},
#      84         event_id=event_id,
#      85     )
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/llms/openai/base.py:732, in OpenAI.achat(self, messages, **kwargs)
#     730 else:
#     731     achat_fn = acompletion_to_chat_decorator(self._acomplete)
# --> 732 return await achat_fn(messages, **kwargs)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:189, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#     187 copy = self.copy()
#     188 async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 189 return await copy(fn, *args, **kwargs)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     109 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#     113         try:
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     151 result = None
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     112 if isinstance(do, DoAttempt):
#     113     try:
# --> 114         result = await fn(*args, **kwargs)
#     115     except BaseException:  # noqa: B902
#     116         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/llama_index/llms/openai/base.py:787, in OpenAI._achat(self, messages, **kwargs)
#     781 message_dicts = to_openai_message_dicts(
#     782     messages,
#     783     model=self.model,
#     784 )
#     786 if self.reuse_client:
# --> 787     response = await aclient.chat.completions.create(
#     788         messages=message_dicts, stream=False, **self._get_model_kwargs(**kwargs)
#     789     )
#     790 else:
#     791     async with aclient:
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:2585, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2539 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2540 async def create(
#    2541     self,
#    (...)   2582     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2583 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2584     validate_response_format(response_format)
# -> 2585     return await self._post(
#    2586         "/chat/completions",
#    2587         body=await async_maybe_transform(
#    2588             {
#    2589                 "messages": messages,
#    2590                 "model": model,
#    2591                 "audio": audio,
#    2592                 "frequency_penalty": frequency_penalty,
#    2593                 "function_call": function_call,
#    2594                 "functions": functions,
#    2595                 "logit_bias": logit_bias,
#    2596                 "logprobs": logprobs,
#    2597                 "max_completion_tokens": max_completion_tokens,
#    2598                 "max_tokens": max_tokens,
#    2599                 "metadata": metadata,
#    2600                 "modalities": modalities,
#    2601                 "n": n,
#    2602                 "parallel_tool_calls": parallel_tool_calls,
#    2603                 "prediction": prediction,
#    2604                 "presence_penalty": presence_penalty,
#    2605                 "prompt_cache_key": prompt_cache_key,
#    2606                 "reasoning_effort": reasoning_effort,
#    2607                 "response_format": response_format,
#    2608                 "safety_identifier": safety_identifier,
#    2609                 "seed": seed,
#    2610                 "service_tier": service_tier,
#    2611                 "stop": stop,
#    2612                 "store": store,
#    2613                 "stream": stream,
#    2614                 "stream_options": stream_options,
#    2615                 "temperature": temperature,
#    2616                 "tool_choice": tool_choice,
#    2617                 "tools": tools,
#    2618                 "top_logprobs": top_logprobs,
#    2619                 "top_p": top_p,
#    2620                 "user": user,
#    2621                 "verbosity": verbosity,
#    2622                 "web_search_options": web_search_options,
#    2623             },
#    2624             completion_create_params.CompletionCreateParamsStreaming
#    2625             if stream
#    2626             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2627         ),
#    2628         options=make_request_options(
#    2629             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2630         ),
#    2631         cast_to=ChatCompletion,
#    2632         stream=stream or False,
#    2633         stream_cls=AsyncStream[ChatCompletionChunk],
#    2634     )
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/github_repos/RAG_Techniques/.venv/lib/python3.13/site-packages/openai/_base_client.py:1594, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1591             await err.response.aread()
#    1593         log.debug("Re-raising status error")
# -> 1594         raise self._make_status_error_from_response(err.response) from None
#    1596     break
#    1598 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-5-nano in organization org-CF1XCwro152qI3UIuvnvBKFp on tokens per min (TPM): Limit 200000, Used 200000, Requested 344. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ### Define metrics evaluators and modify llama_index faithfullness evaluator prompt to rely on the context

# %%
# Define Faithfulness Evaluators which are based on GPT-5
faithfulness_gpt5 = FaithfulnessEvaluator()

faithfulness_new_prompt_template = PromptTemplate(""" Please tell if a given piece of information is directly supported by the context.
    You need to answer with either YES or NO.
    Answer YES if any part of the context explicitly supports the information, even if most of the context is unrelated. If the context does not explicitly support the information, answer NO. Some examples are provided below.

    Information: Apple pie is generally double-crusted.
    Context: An apple pie is a fruit pie in which the principal filling ingredient is apples.
    Apple pie is often served with whipped cream, ice cream ('apple pie à la mode'), custard, or cheddar cheese.
    It is generally double-crusted, with pastry both above and below the filling; the upper crust may be solid or latticed (woven of crosswise strips).
    Answer: YES

    Information: Apple pies taste bad.
    Context: An apple pie is a fruit pie in which the principal filling ingredient is apples.
    Apple pie is often served with whipped cream, ice cream ('apple pie à la mode'), custard, or cheddar cheese.
    It is generally double-crusted, with pastry both above and below the filling; the upper crust may be solid or latticed (woven of crosswise strips).
    Answer: NO

    Information: Paris is the capital of France.
    Context: This document describes a day trip in Paris. You will visit famous landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral.
    Answer: NO

    Information: {query_str}
    Context: {context_str}
    Answer:

    """)

faithfulness_gpt5.update_prompts({"your_prompt_key": faithfulness_new_prompt_template}) # Update the prompts dictionary with the new prompt template

# Define Relevancy Evaluators which are based on GPT-4
relevancy_gpt5 = RelevancyEvaluator()

# %% [markdown]
# ### Function to evaluate metrics for each chunk size

# %%
# Define function to calculate average response time, average faithfulness and average relevancy metrics for given chunk size
# We use GPT-3.5-Turbo to generate response and GPT-4 to evaluate it.
def evaluate_response_time_and_accuracy(chunk_size, eval_questions):
    """
    Evaluate the average response time, faithfulness, and relevancy of responses generated by GPT-3.5-turbo for a given chunk size.
    
    Parameters:
    chunk_size (int): The size of data chunks being processed.
    
    Returns:
    tuple: A tuple containing the average response time, faithfulness, and relevancy metrics.
    """

    total_response_time = 0
    total_faithfulness = 0
    total_relevancy = 0

    # create vector index
    llm = OpenAI(model="gpt-5-nano")

    Settings.llm = llm
    Settings.chunk_size = chunk_size
    Settings.chunk_overlap = chunk_size // 5 

    vector_index = VectorStoreIndex.from_documents(eval_documents)
    
    # build query engine
    query_engine = vector_index.as_query_engine(similarity_top_k=5)
    num_questions = len(eval_questions)

    # Iterate over each question in eval_questions to compute metrics.
    # While BatchEvalRunner can be used for faster evaluations (see: https://docs.llamaindex.ai/en/latest/examples/evaluation/batch_eval.html),
    # we're using a loop here to specifically measure response time for different chunk sizes.
    for question in eval_questions:
        start_time = time.time()
        response_vector = query_engine.query(question)
        elapsed_time = time.time() - start_time
        
        faithfulness_result = faithfulness_gpt5.evaluate_response(
            response=response_vector
        ).passing
        
        relevancy_result = relevancy_gpt5.evaluate_response(
            query=question, response=response_vector
        ).passing

        total_response_time += elapsed_time
        total_faithfulness += faithfulness_result
        total_relevancy += relevancy_result

    average_response_time = total_response_time / num_questions
    average_faithfulness = total_faithfulness / num_questions
    average_relevancy = total_relevancy / num_questions

    return average_response_time, average_faithfulness, average_relevancy

# %% [markdown]
# ### Test different chunk sizes

# %%
chunk_sizes = [128, 256]

for chunk_size in chunk_sizes:
  avg_response_time, avg_faithfulness, avg_relevancy = evaluate_response_time_and_accuracy(chunk_size, k_eval_questions)
  print(f"Chunk size {chunk_size} - Average Response time: {avg_response_time:.2f}s, Average Faithfulness: {avg_faithfulness:.2f}, Average Relevancy: {avg_relevancy:.2f}")
# Out:
# C:\Users\N7\AppData\Local\Temp\ipykernel_22672\1178342312.py:21: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, chunk_size=chunk_size, chunk_overlap=chunk_size//5)
# Chunk size 128 - Average Response time: 1.35s, Average Faithfulness: 1.00, Average Relevancy: 1.00
# Chunk size 256 - Average Response time: 1.31s, Average Faithfulness: 1.00, Average Relevancy: 1.00

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--choose-chunk-size)
